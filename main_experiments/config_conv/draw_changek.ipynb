# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean_acc=np.array([
    [0.7491,0.7168,0.6350,0.6222,0.7147,0.5910], 
    [0.7670,0.7521,0.7915,0.7833,0.8225,0.6637], 
    [0.7571,0.7345,0.8012,0.7870,0.8241,0.6738], 
    [0.7562,0.7277,0.7932,0.7889,0.8278,0.6860], 
    [0.7750,0.7328,0.8092,0.7988,0.8246,0.6899]]).T

std_acc=np.array([
    [0.0300,0.0493,0.0298,0.0257,0.0266,0.0292], 
    [0.0384,0.0269,0.0225,0.0181,0.0194,0.0138], 
    [0.0397,0.0432,0.0227,0.0208,0.0264,0.0190], 
    [0.0296,0.0385,0.0248,0.0183,0.0221,0.0152], 
    [0.0391,0.0461,0.0183,0.0131,0.0174,0.0202], 
]).T

# %%
ID=np.array([[3.8503,1.0700,0.3455,0.1315,0.0603,0.0306,0.0175,0.0100],
            [7.0546,1.5698,0.7453,0.4308,0.2739,0.1748,0.1135,0.0741],
            [7.4610,0.9752,0.4677,0.1911,0.1312,0.0635,0.0507,0.0240],
            [5.5049,1.0010,0.4762,0.1943,0.1315,0.0632,0.0514,0.0239],
            [6.4713,0.7819,0.5094,0.1421,0.1311,0.0398,0.0376,0.0134],
            [5.0895,0.6851,0.3016,0.1003,0.0631,0.0261,0.0175,0.0073]])

# %%
['Pro','DD','NCI1','NCI109','Mut','Far']

# x=range(1,6)
# plt.plot(x,mean_acc[0],c='C0',linestyle='--',marker='o',label='Pro')
# plt.fill_between(x, mean_acc[0]-std_acc[0],mean_acc[0]+std_acc[0],color='C0',alpha=0.3)
# # plt.scatter(range(1,6),mean_acc[0],c='C0',label='Pro')

# plt.plot(range(1,6),mean_acc[2],c='C2',linestyle='--',marker='x',label='NCI1')
# plt.fill_between(x, mean_acc[2]-std_acc[2],mean_acc[2]+std_acc[2],color='C2',alpha=0.3)

# plt.plot(range(1,6),mean_acc[4],c='C4',linestyle='--',marker='s',label='Mut')
# plt.fill_between(x, mean_acc[4]-std_acc[4],mean_acc[4]+std_acc[4],color='C4',alpha=0.3)

# plt.ylim([0.55,0.85])
# plt.xlim([0.97,5.03])
# plt.xticks([1,2,3,4,5])
# plt.legend(loc='lower right')
# plt.savefig('acc_change_k_01.png')

plt.plot(range(1,6),mean_acc[1],c='C1',linestyle='--',marker='o',label='DD')
plt.fill_between(x, mean_acc[1]-std_acc[1],mean_acc[1]+std_acc[1],color='C1',alpha=0.3)

plt.plot(range(1,6),mean_acc[3],c='C3',linestyle='--',marker='x',label='NCI109')
plt.fill_between(x, mean_acc[3]-std_acc[3],mean_acc[3]+std_acc[3],color='C3',alpha=0.3)

plt.plot(range(1,6),mean_acc[5],c='C5',linestyle='--',marker='s',label='Far')
plt.fill_between(x, mean_acc[5]-std_acc[5],mean_acc[5]+std_acc[5],color='C5',alpha=0.3)

plt.ylim([0.55,0.85])
plt.xlim([0.97,5.03])
plt.xticks([1,2,3,4,5])
plt.legend(loc='lower right')
plt.savefig('acc_change_k_02.png')

# %%
plt.plot(range(1,6),mean_acc[0],c='C0',linestyle='--')
plt.plot(range(1,6),mean_acc[1],c='C1',linestyle='--')
plt.plot(range(1,6),mean_acc[2],c='C2',linestyle='--')
plt.plot(range(1,6),mean_acc[3],c='C3',linestyle='--')
plt.plot(range(1,6),mean_acc[4],c='C4',linestyle='--')
plt.plot(range(1,6),mean_acc[5],c='C5',linestyle='--')

plt.scatter(range(1,6),mean_acc[0],c='C0',label='Pro')
plt.scatter(range(1,6),mean_acc[1],c='C1',label='DD')
plt.scatter(range(1,6),mean_acc[2],c='C2',label='NCI1')
plt.scatter(range(1,6),mean_acc[3],c='C3',label='NCI109')
plt.scatter(range(1,6),mean_acc[4],c='C4',label='Mut')
plt.scatter(range(1,6),mean_acc[5],c='C5',label='Far')

plt.legend()

# %%
def func(x,b,a):
    return a*np.exp(-b*x)

# %%
plt.scatter(range(2,10),ID[0],c='C0',label='Pro')
plt.scatter(range(2,10),ID[1],c='C1',label='DD')
plt.scatter(range(2,10),ID[2],c='C2',label='NCI1')
plt.scatter(range(2,10),ID[3],c='C3',label='NCI109')
plt.scatter(range(2,10),ID[4],c='C4',label='Mut')
plt.scatter(range(2,10),ID[5],c='C5',label='Far')

x=np.linspace(2,9,100)
plt.plot(x,func(x,1.2501,46.8505),linestyle='--',c='C0')
plt.plot(x,func(x,1.3622,107.0625),linestyle='--',c='C1')
plt.plot(x,func(x,1.9339,356.5393),linestyle='--',c='C2')
plt.plot(x,func(x,1.5853,130.821),linestyle='--',c='C3')
plt.plot(x,func(x,1.9743,335.1961),linestyle='--',c='C4')
plt.plot(x,func(x,1.9169,235.0988),linestyle='--',c='C5')

plt.legend()
